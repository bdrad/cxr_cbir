# %%
import os
import pandas as pd
# !pip install pydicom
basedir = '/run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022'

# %%
manifest_dirs = filter(lambda dir: 'manifest' in dir, os.listdir(basedir))
manifest_metadata_dfs = []
for dir in manifest_dirs:
    print(basedir + '/' + dir)
    manifest_metadata_df = pd.read_csv((basedir + '/' + dir + '/metadata.csv'))
    manifest_metadata_dfs.append(manifest_metadata_df)

metadata = pd.concat(manifest_metadata_dfs)
# Out:
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_01-1632928843386
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_02-1632927888500
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_03-1632929488567
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_04-1632930131404
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_05-1632933130941
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_06-1632940796775
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_07-1632960932512
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_08-1632961568183
# /run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_09-1632962146290
# ...

# %%
metadata['Number of Images'].value_counts()
# Out:
# 2      38735
# 1      26183
# 3       4166
# 160     2419
# 151     2121
#        ...
# 573        1
# 682        1
# 596        1
# 495        1
# 460        1
# Name: Number of Images, Length: 556, dtype: int64

# %%
metadata
# Out:
#                                              Series UID Collection  \
# 0     1.2.840.113654.2.55.10705897179139909646804663...       NLST
# 1     1.2.840.113654.2.55.12234416849703812802252490...       NLST
# 2     1.2.840.113654.2.55.97114726565566537928831413...       NLST
# 3     1.2.840.113654.2.55.22965053110171620353624164...       NLST
# 4     1.2.840.113654.2.55.25792656269360766386536917...       NLST
# ...                                                 ...        ...
# 8804  1.3.6.1.4.1.14519.5.2.1.7009.9004.996994076327...       NLST
# 8805  1.3.6.1.4.1.14519.5.2.1.7009.9004.133612391185...       NLST
# 8806  1.3.6.1.4.1.14519.5.2.1.7009.9004.185781639028...       NLST
# 8807  1.3.6.1.4.1.14519.5.2.1.7009.9004.303926851082...       NLST
# 8808  1.3.6.1.4.1.14519.5.2.1.7009.9004.133609493625...       NLST
#
#       3rd Party Analysis  Data Description URI  Subject ID  \
# 0                    NaN                   NaN      100002
# ...

# %%
folder = '/run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/manifest_01-1632928843386'
folder += metadata.iloc[0]['File Location'][1:]

import pydicom
ds = pydicom.read_file(folder + '/1-1.dcm')
ds.Modality
# Out:
# 'CT'

# %%
# !ls '/NLST/100002/01-02-2001-NA-NLST-LSS-80878/1.000000-2OPLGELSPLUSDnullna1200.00.0null-86083'
# Out:
# ls: cannot access './NLST/100002/01-02-2001-NA-NLST-LSS-80878/1.000000-2OPLGELSPLUSDnullna1200.00.0null-86083': No such file or directory

# %%
os.listdir(basedir + '/manifest_01-1632928843386/NLST/100002/01-02-2001-NA-NLST-LSS-80878/1.000000-2OPLGELSPLUSDnullna1200.00.0null-86083')
# Out:
# ['1-1.dcm', '2-1.dcm']

# %%
# !ls '/run/user/1002/gvfs/smb-share:server=sohn2020.local,share=research/NLST_032022/'
# Out:
# full_pid_list.csv	   manifest_10-1632962895431
# manifest_01-1632928843386  manifest_11-1632963150531
# manifest_02-1632927888500  meta_paths.csv
# manifest_03-1632929488567  meta_paths.p
# manifest_04-1632930131404  NLST_032022full_pid_list.csv
# manifest_05-1632933130941  NLST_pid_indices_list_updated.csv
# manifest_06-1632940796775  NLST_priority_dict.json
# manifest_07-1632960932512  NLST_selected_image_folders_metadata.csv
# manifest_08-1632961568183  NLST_selected_image_folders_metadata_rerun.csv
# manifest_09-1632962146290

# %%
patient_metadata = pd.read_csv('prsn.csv')
patient_metadata
# Out:
# /home/developer/anaconda3/envs/cbir/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (201,224,225) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        smokeage  smokeday  age_quit  cigsmok  gender  rndgroup  age    pkyr  \
# 0           4.0        30       NaN        1       1         2   70   99.00
# 1          14.0        20       NaN        1       1         1   66   52.00
# 2          20.0        30       NaN        1       1         2   64   66.00
# 3          22.0        40      45.0        0       1         1   60   34.00
# 4          15.0        40      61.0        0       1         1   64   92.00
# ...         ...       ...       ...      ...     ...       ...  ...     ...
# 53447       6.0        40       NaN        1       2         1   73  120.00
# 53448      16.0        20       NaN        1       1         2   66   50.00
# ...

# %%
len(metadata['Subject ID'].unique())
# Out:
# 26082

# %%
metadata
# Out:
#                                              Series UID Collection  \
# 0     1.2.840.113654.2.55.10705897179139909646804663...       NLST
# 1     1.2.840.113654.2.55.12234416849703812802252490...       NLST
# 2     1.2.840.113654.2.55.97114726565566537928831413...       NLST
# 3     1.2.840.113654.2.55.22965053110171620353624164...       NLST
# 4     1.2.840.113654.2.55.25792656269360766386536917...       NLST
# ...                                                 ...        ...
# 8804  1.3.6.1.4.1.14519.5.2.1.7009.9004.996994076327...       NLST
# 8805  1.3.6.1.4.1.14519.5.2.1.7009.9004.133612391185...       NLST
# 8806  1.3.6.1.4.1.14519.5.2.1.7009.9004.185781639028...       NLST
# 8807  1.3.6.1.4.1.14519.5.2.1.7009.9004.303926851082...       NLST
# 8808  1.3.6.1.4.1.14519.5.2.1.7009.9004.133609493625...       NLST
#
#       3rd Party Analysis  Data Description URI  Subject ID  \
# 0                    NaN                   NaN      100002
# ...
